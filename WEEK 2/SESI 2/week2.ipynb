# %%
import pandas as pd

# %%
import pandas as pandas
path = "GlobalWeatherReposiroty.csv"
df = pd.read_csv(path)
df
# Out:
#            country     location_name  latitude  longitude         timezone  \
# 0      Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1          Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2          Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3          Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4           Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...            ...               ...       ...        ...              ...
# 39589    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 39590      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 39591        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 39592       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 39593     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
#        last_updated_epoch     last_updated  temperature_celsius  \
# ...

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch     last_updated  temperature_celsius  \
# 0          1715849100  5/16/2024 13:15                 26.6
# 1          1715849100  5/16/2024 10:45                 19.0
# 2          1715849100   5/16/2024 9:45                 23.0
# 3          1715849100  5/16/2024 10:45                  6.3
# 4          1715849100   5/16/2024 9:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#          country location_name  latitude  longitude         timezone  \
# 39589  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 39590    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 39591      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 39592     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 39593   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#        last_updated_epoch     last_updated  temperature_celsius  \
# 39589          1733482800   12/6/2024 7:00                 16.2
# 39590          1733481000  12/6/2024 17:30                 21.2
# 39591          1733481900  12/6/2024 13:45                 22.2
# 39592          1733481900  12/6/2024 12:45                 36.0
# 39593          1733482800  12/6/2024 13:00                 34.7
#
#        temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 39589                    61.2          Sunny  ...             14.430
# ...

# %%
df_noid = df.iloc[:,7]
df_noid
# Out:
# 0        26.6
# 1        19.0
# 2        23.0
# 3         6.3
# 4        26.0
#          ...
# 39589    16.2
# 39590    21.2
# 39591    22.2
# 39592    36.0
# 39593    34.7
# Name: temperature_celsius, Length: 39594, dtype: float64

# %%
df_noid.describe()
# Out:
# count    39594.000000
# mean        24.350599
# std          8.130323
# min        -21.900000
# 25%         20.200000
# 50%         26.100000
# 75%         29.200000
# max         49.200000
# Name: temperature_celsius, dtype: float64

# %%
df_noid[['pressure_mb','humidity']].mean()
# Out:
# pressure_mb    1013.195914
# humidity         62.528237
# dtype: float64

# %%
df_noid[['temperature_celsius', 'humidity','air_quality_Ozone']].corr()
# Out:
#                      temperature_celsius  humidity  air_quality_Ozone
# temperature_celsius             1.000000 -0.420825           0.334880
# humidity                       -0.420825  1.000000          -0.508499
# air_quality_Ozone               0.334880 -0.508499           1.000000

# %% [markdown]
# Tugas 1 Week 2_42324043 Sophia Melisa Silitonga

# %% [markdown]
# Nomor 1

# %%
# Analisis korelasi Tugas 1
df_noid[['temperature_fahrenheit',
         'pressure_mb',
         'air_quality_Sulphur_dioxide']].corr()
# Out:
#                              temperature_fahrenheit  pressure_mb  \
# temperature_fahrenheit                     1.000000    -0.486833
# pressure_mb                               -0.486833     1.000000
# air_quality_Sulphur_dioxide               -0.023152     0.018620
#
#                              air_quality_Sulphur_dioxide
# temperature_fahrenheit                         -0.023152
# pressure_mb                                     0.018620
# air_quality_Sulphur_dioxide                     1.000000

# %% [markdown]
# Hasil Analisis No.1
#
# 1.Temperature Fahrenheit dan Pressure mb = -0.486833,
# Menunjukkan hubungan negatif sedang. Saat suhu meningkat, tekanan udara cenderung menurun.
#
# 2.Temperature Fahrenheit dan Sulphur dioxide = -0.023152,
# Menunjukkan hubungan sangat lemah atau hampir tidak ada.
#
# 3.Pressure mb dan Sulphur dioxide = 0.018620,
# Menunjukkan hubungan positif yang sangat lemah atau hampir tidak ada.
#
# Kesimpulan:
# Hubungan paling terlihat adalah antara temperature Fahrenheit dan pressure mb dengan korelasi -0.486833. Dua pasangan lainnya memiliki korelasi yang sangat lemah karena nilain

# %% [markdown]
# Nomor 2A Analisa mean, std, min, max, Q1, Q2, Q3 untuk data Previous Purchases
# (Dengan DATASET shopping_trends.csv)

# %%
import pandas as pd

df_customer = pd.read_csv("shopping_trends.csv")

df_customer.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df_customer['Previous Purchases'].describe()[['mean', 'std', 'min', 'max', '25%', '50%', '75%']]
# Out:
# mean    25.351538
# std     14.447125
# min      1.000000
# max     50.000000
# 25%     13.000000
# 50%     25.000000
# 75%     38.000000
# Name: Previous Purchases, dtype: float64

# %% [markdown]
# Hasil Analisis:
#
# Rata-rata jumlah pembelian sebelumnya adalah 25,35 kali. Nilai terendah adalah 1 kali dan tertinggi 50 kali.
# Sebanyak 50% data berada pada rentang 13–38 pembelian sebelumnya.

# %% [markdown]
# Nomor 2B Analisa korelasi Age vs Purchase Amount (USD) dan Purchase Amount (USD) vs Review Rating
# (Dengan DATASET shopping_trends.csv)

# %% [markdown]
# 1.Korelasi Age vs Purchase Amount (USD)

# %%
df_customer[['Age', 'Purchase Amount (USD)']].corr()
# Out:
#                             Age  Purchase Amount (USD)
# Age                    1.000000              -0.010424
# Purchase Amount (USD) -0.010424               1.000000

# %% [markdown]
# Hasil Analisis:    Age vs Purchase Amount (USD) = -0,010424
# Nilainya sangat mendekati 0, sehingga hubungan antara usia dan jumlah pembelian sangat lemah atau hampir tidak ada.

# %% [markdown]
# 2. Korelasi Purchase Amount (USD) vs Review Rating

# %%
df_customer[['Purchase Amount (USD)', 'Review Rating']].corr()
# Out:
#                        Purchase Amount (USD)  Review Rating
# Purchase Amount (USD)               1.000000       0.030776
# Review Rating                       0.030776       1.000000

# %% [markdown]
# Hasil Analisis :Purchase Amount (USD) vs Review Rating = 0,030776
# Nilainya juga sangat mendekati 0, sehingga hubungan antara jumlah pembelian dan rating ulasan sangat lemah atau hampir tidak ada.

# %% [markdown]
# KESIMPULAN: Kedua variabel tersebut memiliki hubungan linear yang sangat lemah, karena nilai korelasinya mendekati 0.
